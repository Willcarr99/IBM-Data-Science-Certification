# %% [markdown]
# # My Jupyter Notebook on Watson Studio

# %% [markdown]
# **William Fox**

# %% [markdown]
# Graduate Research Assistant

# %% [markdown]
# *I am interested in data science because its predictive power is fascinating. I also love coding and have a strong background in mathematics and statistics.*

# %% [markdown]
# ### The following code multiplies all elements in a list.

# %%
def mult_nums(num_list):
    val = 1
    for i in num_list:
        val = i * val
    return val

example_list = [5,8,2]
mult_nums(example_list)
# Out:
# 80

# %% [markdown]
# This is an example of code/syntax highlighting:
# ```python
# str = "Hello World!"
# print(str)
# ```
#
# * This
# * Is
# * A
# * Very
# * Nice
# * List
#
# This | Is | A | Table
# :---:|:---:|:---:|:---:
# It | is | **my** | table
# A | very | small | table
# But | it | is | mine
